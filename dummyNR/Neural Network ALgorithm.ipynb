# %%
import numpy as np
import pandas as pd
from random import random
from math import exp

# %%
data = pd.read_csv('data/seeds_dataset.txt',delim_whitespace=True,header=None)

# %%
data.head(10)
# Out:
#        0      1       2      3      4      5      6  7
# 0  15.26  14.84  0.8710  5.763  3.312  2.221  5.220  1
# 1  14.88  14.57  0.8811  5.554  3.333  1.018  4.956  1
# 2  14.29  14.09  0.9050  5.291  3.337  2.699  4.825  1
# 3  13.84  13.94  0.8955  5.324  3.379  2.259  4.805  1
# 4  16.14  14.99  0.9034  5.658  3.562  1.355  5.175  1
# 5  14.38  14.21  0.8951  5.386  3.312  2.462  4.956  1
# 6  14.69  14.49  0.8799  5.563  3.259  3.586  5.219  1
# 7  14.11  14.10  0.8911  5.420  3.302  2.700  5.000  1
# 8  16.63  15.46  0.8747  6.053  3.465  2.040  5.877  1
# 9  16.44  15.25  0.8880  5.884  3.505  1.969  5.533  1

# %%
features = list(data)[:-1]
target = 7

# %%
for feature in features:
    curr_max = max(data[feature])
    curr_min = min(data[feature])
    data[feature] = data[feature].apply(lambda x : x/(curr_max-curr_min))
data['output'] = data[target].apply(lambda x: [1 if i==x-1 else 0 for i in range(3)])

# %%
data.tail(5)
# Out:
#             0         1         2         3         4         5         6  7  \
# 205  1.151086  2.727273  7.970054  2.892455  2.124733  0.472116  2.397834  3
# 206  1.060434  2.661157  7.723230  2.894144  1.992160  0.562353  2.463319  3
# 207  1.246459  2.822314  8.060799  2.948198  2.303635  1.081148  2.489414  3
# 208  1.118036  2.729339  7.732305  2.913851  2.021383  0.467826  2.483506  3
# 209  1.161473  2.756198  7.880218  2.952140  2.119743  0.732944  2.492861  3
#
#         output
# 205  [0, 0, 1]
# 206  [0, 0, 1]
# 207  [0, 0, 1]
# 208  [0, 0, 1]
# 209  [0, 0, 1]

# %% [markdown]
# # Normalized the data set

# %% [markdown]
# ### Buliding a network

# %%
def create_network(n_inputs,n_hidden,n_outputs):
    network = []
    # initializing random weights for hidden and output layer
    hidden = [{'weights':[random() for i in range(n_inputs+1)]} for i in range(n_hidden)]
    network.append(hidden)
    output = [{'weights':[random() for i in range(n_hidden + 1)]} for i in range(n_outputs)]
    network.append(output)
    return network

# %%
from random import seed
seed(1)
test_network = create_network(2,1,2)
for layer in network:
    print layer
# Out:
# [{'weights': [0.13436424411240122, 0.8474337369372327, 0.763774618976614]}]
# [{'weights': [0.2550690257394217, 0.49543508709194095]}, {'weights': [0.4494910647887381, 0.651592972722763]}]

# %% [markdown]
# # Forward propagation

# %% [markdown]
# ### Activating neurons

# %%
def activate_neuron(weights,inputs):
    activation = weights[-1] #initializing with bias weight
    for i in range(len(weights)-1):
        activation += weights[i]*inputs[i]
    return activation

# %% [markdown]
# ### Transferring neuron data

# %%
def transfer_neuron_data(activation):
    return 1/(1+exp(-1*activation))

# %% [markdown]
# ### Propagating information forward

# %%
def forward_propagation(network,inputs):
    inputs = list(inputs)
    for layer in network:
        next_inputs = []
        for neuron in layer:
            
            activation = activate_neuron(neuron['weights'],inputs)
            neuron['output'] = transfer_neuron_data(activation)
            next_inputs.append(neuron['output'])
        inputs = next_inputs
    return inputs

# %% [markdown]
# # Testing forward propagation with dummy network

# %%
row = [1,0,None]
output = forward_propagation(test_network,row)
print output
# Out:
# [0.6629970129852887, 0.7253160725279748]

# %% [markdown]
# # Backward propagation

# %% [markdown]
# ### Sending derivative backward

# %%
def send_derivative(output):
    return output*(1.0-output)

# %% [markdown]
# ### propagating error backwards

# %%
def backward_propagate_error(network,output):
    for i in reversed(range(len(network))):
        layer = network[i]
        errors = []
        if i != len(network)-1: # All networks except the last one
            for j in range(len(layer)):
                error = 0.0
                for neuron in network[i+1]:
                    error += (neuron['weights'][j]*neuron['delta'])
                errors.append(error)
        else:
            for j in range(len(layer)): # error for the last layer
                neuron = layer[j]
                error = output[j] - neuron['output']
                errors.append(error)
        for j in range(len(layer)):
            neuron = layer[j]
            neuron['delta'] = errors[j]*send_derivative(neuron['output'])

# %% [markdown]
# ## Testing backward propagation

# %%
expected = [0,1]
backward_propagate_error(test_network,expected)
for layer in test_network:
    print layer
# Out:
# [{'output': 0.7105668883115941, 'weights': [0.13436424411240122, 0.8474337369372327, 0.763774618976614], 'delta': -0.002711797799238243}]
# [{'output': 0.6629970129852887, 'weights': [0.2550690257394217, 0.49543508709194095], 'delta': -0.14813473120687762}, {'output': 0.7253160725279748, 'weights': [0.4494910647887381, 0.651592972722763], 'delta': 0.05472601157879688}]

# %% [markdown]
# # Training Network now

# %% [markdown]
# ### updating weights

# %%
def update_weights(network,inputs,l_rate):#l_rate is the learning rate
    for i in range(len(network)):
        inputs = inputs[:-1] # No need to update dummy neurons
        if i != 0:
            inputs = [neuron['output'] for neuron in network[i-1]]
        for neuron in network[i]:
            for j in range(len(inputs)):
                neuron['weights'][j] += l_rate*neuron['delta']*inputs[j]
            neuron['weights'][-1] += l_rate*neuron['delta']

# %% [markdown]
# ## Iterations to improve error

# %%
def train_network(network,data,l_rate,n_iter,n_outputs):
    for n in range(n_iter):
        sum_error = 0
        for i in range(len(data)):
            row = list(data[features].iloc[i])
            prediction = forward_propagation(network,row)
            expectation = data['output'].iloc[i]
            sum_error += sum([(expectation[j] - prediction[j])**2 for j in range(len(prediction))])
            backward_propagate_error(network,expectation)
            update_weights(network,row,l_rate)
        print "Iteration : ",n,"l_rate : ",l_rate," Error : ",sum_error

# %%
test_network = create_network(len(features),10,3)
train_network(test_network,data,0.5,100,3)
# Out:
# Iteration :  0 l_rate :  0.5  Error :  247.956691317
# Iteration :  1 l_rate :  0.5  Error :  169.190797365
# Iteration :  2 l_rate :  0.5  Error :  169.87459132
# Iteration :  3 l_rate :  0.5  Error :  169.665486878
# Iteration :  4 l_rate :  0.5  Error :  111.059703054
# Iteration :  5 l_rate :  0.5  Error :  45.1978069118
# Iteration :  6 l_rate :  0.5  Error :  45.0918188672
# Iteration :  7 l_rate :  0.5  Error :  45.091666875
# Iteration :  8 l_rate :  0.5  Error :  45.091665085
# Iteration :  9 l_rate :  0.5  Error :  45.0916635045
# Iteration :  10 l_rate :  0.5  Error :  45.0916619208
# Iteration :  11 l_rate :  0.5  Error :  45.0916603333
# Iteration :  12 l_rate :  0.5  Error :  45.0916587421
# Iteration :  13 l_rate :  0.5  Error :  45.091657147
# Iteration :  14 l_rate :  0.5  Error :  45.0916555481
# Iteration :  15 l_rate :  0.5  Error :  45.0916539452
# Iteration :  16 l_rate :  0.5  Error :  45.0916523382
# Iteration :  17 l_rate :  0.5  Error :  45.0916507272
# Iteration :  18 l_rate :  0.5  Error :  45.091649112
# Iteration :  19 l_rate :  0.5  Error :  45.0916474925
# Iteration :  20 l_rate :  0.5  Error :  45.0916458687
# Iteration :  21 l_rate :  0.5  Error :  45.0916442405
# Iteration :  22 l_rate :  0.5  Error :  45.0916426078
# Iteration :  23 l_rate :  0.5  Error :  45.0916409705
# Iteration :  24 l_rate :  0.5  Error :  45.0916393286
# Iteration :  25 l_rate :  0.5  Error :  45.091637682
# Iteration :  26 l_rate :  0.5  Error :  45.0916360306
# Iteration :  27 l_rate :  0.5  Error :  45.0916343744
# Iteration :  28 l_rate :  0.5  Error :  45.0916327131
# Iteration :  29 l_rate :  0.5  Error :  45.0916310469
# Iteration :  30 l_rate :  0.5  Error :  45.0916293754
# Iteration :  31 l_rate :  0.5  Error :  45.0916276988
# Iteration :  32 l_rate :  0.5  Error :  45.0916260169
# Iteration :  33 l_rate :  0.5  Error :  45.0916243295
# Iteration :  34 l_rate :  0.5  Error :  45.0916226367
# Iteration :  35 l_rate :  0.5  Error :  45.0916209383
# Iteration :  36 l_rate :  0.5  Error :  45.0916192342
# Iteration :  37 l_rate :  0.5  Error :  45.0916175244
# Iteration :  38 l_rate :  0.5  Error :  45.0916158087
# Iteration :  39 l_rate :  0.5  Error :  45.091614087
# Iteration :  40 l_rate :  0.5  Error :  45.0916123593
# Iteration :  41 l_rate :  0.5  Error :  45.0916106254
# Iteration :  42 l_rate :  0.5  Error :  45.0916088852
# Iteration :  43 l_rate :  0.5  Error :  45.0916071387
# Iteration :  44 l_rate :  0.5  Error :  45.0916053857
# Iteration :  45 l_rate :  0.5  Error :  45.0916036261
# Iteration :  46 l_rate :  0.5  Error :  45.0916018598
# Iteration :  47 l_rate :  0.5  Error :  45.0916000867
# Iteration :  48 l_rate :  0.5  Error :  45.0915983067
# Iteration :  49 l_rate :  0.5  Error :  45.0915965197
# Iteration :  50 l_rate :  0.5  Error :  45.0915947255
# Iteration :  51 l_rate :  0.5  Error :  45.091592924
# Iteration :  52 l_rate :  0.5  Error :  45.0915911151
# Iteration :  53 l_rate :  0.5  Error :  45.0915892988
# Iteration :  54 l_rate :  0.5  Error :  45.0915874748
# Iteration :  55 l_rate :  0.5  Error :  45.091585643
# Iteration :  56 l_rate :  0.5  Error :  45.0915838034
# Iteration :  57 l_rate :  0.5  Error :  45.0915819557
# Iteration :  58 l_rate :  0.5  Error :  45.0915800998
# Iteration :  59 l_rate :  0.5  Error :  45.0915782357
# Iteration :  60 l_rate :  0.5  Error :  45.0915763632
# Iteration :  61 l_rate :  0.5  Error :  45.091574482
# Iteration :  62 l_rate :  0.5  Error :  45.0915725922
# Iteration :  63 l_rate :  0.5  Error :  45.0915706935
# Iteration :  64 l_rate :  0.5  Error :  45.0915687858
# Iteration :  65 l_rate :  0.5  Error :  45.0915668689
# Iteration :  66 l_rate :  0.5  Error :  45.0915649427
# Iteration :  67 l_rate :  0.5  Error :  45.0915630071
# Iteration :  68 l_rate :  0.5  Error :  45.0915610618
# Iteration :  69 l_rate :  0.5  Error :  45.0915591068
# Iteration :  70 l_rate :  0.5  Error :  45.0915571418
# Iteration :  71 l_rate :  0.5  Error :  45.0915551666
# Iteration :  72 l_rate :  0.5  Error :  45.0915531812
# Iteration :  73 l_rate :  0.5  Error :  45.0915511853
# Iteration :  74 l_rate :  0.5  Error :  45.0915491788
# Iteration :  75 l_rate :  0.5  Error :  45.0915471615
# Iteration :  76 l_rate :  0.5  Error :  45.0915451331
# Iteration :  77 l_rate :  0.5  Error :  45.0915430936
# Iteration :  78 l_rate :  0.5  Error :  45.0915410427
# Iteration :  79 l_rate :  0.5  Error :  45.0915389802
# Iteration :  80 l_rate :  0.5  Error :  45.0915369059
# Iteration :  81 l_rate :  0.5  Error :  45.0915348196
# Iteration :  82 l_rate :  0.5  Error :  45.0915327212
# Iteration :  83 l_rate :  0.5  Error :  45.0915306103
# Iteration :  84 l_rate :  0.5  Error :  45.0915284869
# Iteration :  85 l_rate :  0.5  Error :  45.0915263506
# Iteration :  86 l_rate :  0.5  Error :  45.0915242012
# Iteration :  87 l_rate :  0.5  Error :  45.0915220386
# Iteration :  88 l_rate :  0.5  Error :  45.0915198625
# Iteration :  89 l_rate :  0.5  Error :  45.0915176726
# Iteration :  90 l_rate :  0.5  Error :  45.0915154687
# Iteration :  91 l_rate :  0.5  Error :  45.0915132506
# Iteration :  92 l_rate :  0.5  Error :  45.091511018
# Iteration :  93 l_rate :  0.5  Error :  45.0915087707
# Iteration :  94 l_rate :  0.5  Error :  45.0915065083
# Iteration :  95 l_rate :  0.5  Error :  45.0915042307
# Iteration :  96 l_rate :  0.5  Error :  45.0915019375
# Iteration :  97 l_rate :  0.5  Error :  45.0914996285
# Iteration :  98 l_rate :  0.5  Error :  45.0914973034
# Iteration :  99 l_rate :  0.5  Error :  45.0914949618

# %% [markdown]
# ### Making predictions

# %%
def predict(network,inputs):
    output = forward_propagation(network,inputs)
    return output

# %%
print forward_propagation(test_network,data[features].iloc[11])
# Out:
# [0.02736703749828073, 0.04046183719327358, 0.9586015817064812]

# %%
data.head(100)
# Out:
#            0         1         2         3         4         5         6  7  \
# 0   1.440982  3.066116  7.903811  3.244932  2.360656  0.288783  2.570162  1
# 1   1.405099  3.010331  7.995463  3.127252  2.375624  0.132364  2.440177  1
# 2   1.349386  2.911157  8.212341  2.979167  2.378475  0.350934  2.375677  1
# 3   1.306893  2.880165  8.126134  2.997748  2.408411  0.293724  2.365830  1
# 4   1.524079  3.097107  8.197822  3.185811  2.538845  0.176182  2.548006  1
# 5   1.357885  2.935950  8.122505  3.032658  2.360656  0.320119  2.440177  1
# 6   1.387158  2.993802  7.984574  3.132320  2.322880  0.466265  2.569670  1
# 7   1.332389  2.913223  8.086207  3.051802  2.353528  0.351064  2.461841  1
# 8   1.570349  3.194215  7.937387  3.408221  2.469708  0.265249  2.893648  1
# 9   1.552408  3.150826  8.058076  3.313063  2.498218  0.256017  2.724274  1
# 10  1.440982  3.068182  7.891107  3.217342  2.310763  0.590698  2.616445  1
# 11  1.324835  2.925620  7.981851  3.061937  2.281540  0.223251  2.462334  1
# 12  1.311615  2.896694  8.058076  3.062500  2.280114  0.518275  2.332841  1
# 92  1.776204  3.365702  8.081670  3.531532  2.632217  0.420887  2.980305  2
# 93  1.755430  3.316116  8.226860  3.399212  2.751247  0.780273  2.893648  2
# 94  1.733711  3.413223  7.669691  3.753378  2.483963  0.641407  3.174791  2
# 95  1.593012  3.233471  7.847550  3.456644  2.468282  0.480568  2.937962  2
# 96  1.823418  3.427686  7.999093  3.570383  2.715609  0.452093  3.071393  2
# 97  1.792257  3.423554  7.882940  3.631194  2.531718  0.278771  3.177253  2
# 98  1.715770  3.359504  7.837568  3.530968  2.503207  0.370958  3.088626  2
# 99  1.767705  3.376033  7.994555  3.501689  2.625802  0.284492  3.001969  2
#
#        output  prediction
# 0   [1, 0, 0]           3
# 1   [1, 0, 0]           3
# 2   [1, 0, 0]           3
# 3   [1, 0, 0]           3
# 4   [1, 0, 0]           3
# 5   [1, 0, 0]           3
# 6   [1, 0, 0]           3
# 7   [1, 0, 0]           3
# 8   [1, 0, 0]           3
# 9   [1, 0, 0]           3
# 10  [1, 0, 0]           3
# 11  [1, 0, 0]           3
# 12  [1, 0, 0]           3
# 13  [1, 0, 0]           3
# 14  [1, 0, 0]           3
# 15  [1, 0, 0]           3
# 16  [1, 0, 0]           3
# 17  [1, 0, 0]           3
# 18  [1, 0, 0]           3
# 19  [1, 0, 0]           3
# 20  [1, 0, 0]           3
# 21  [1, 0, 0]           3
# 22  [1, 0, 0]           3
# 23  [1, 0, 0]           3
# 24  [1, 0, 0]           3
# 25  [1, 0, 0]           3
# 26  [1, 0, 0]           3
# 27  [1, 0, 0]           3
# 28  [1, 0, 0]           3
# 29  [1, 0, 0]           3
# ..        ...         ...
# 70  [0, 1, 0]           3
# 71  [0, 1, 0]           3
# 72  [0, 1, 0]           3
# 73  [0, 1, 0]           3
# 74  [0, 1, 0]           3
# 75  [0, 1, 0]           3
# 76  [0, 1, 0]           3
# 77  [0, 1, 0]           3
# 78  [0, 1, 0]           3
# 79  [0, 1, 0]           3
# 80  [0, 1, 0]           3
# 81  [0, 1, 0]           3
# 82  [0, 1, 0]           3
# 83  [0, 1, 0]           3
# 84  [0, 1, 0]           3
# 85  [0, 1, 0]           3
# 86  [0, 1, 0]           3
# 87  [0, 1, 0]           3
# 88  [0, 1, 0]           3
# 89  [0, 1, 0]           3
# 90  [0, 1, 0]           3
# 91  [0, 1, 0]           3
# 92  [0, 1, 0]           3
# 93  [0, 1, 0]           3
# 94  [0, 1, 0]           3
# 95  [0, 1, 0]           3
# 96  [0, 1, 0]           3
# 97  [0, 1, 0]           3
# 98  [0, 1, 0]           3
# 99  [0, 1, 0]           3
#
# [100 rows x 10 columns]

# %%
data.head(100)
# Out:
#            0         1         2         3         4         5         6  7  \
# 0   1.440982  3.066116  7.903811  3.244932  2.360656  0.288783  2.570162  1
# 1   1.405099  3.010331  7.995463  3.127252  2.375624  0.132364  2.440177  1
# 2   1.349386  2.911157  8.212341  2.979167  2.378475  0.350934  2.375677  1
# 3   1.306893  2.880165  8.126134  2.997748  2.408411  0.293724  2.365830  1
# 4   1.524079  3.097107  8.197822  3.185811  2.538845  0.176182  2.548006  1
# 5   1.357885  2.935950  8.122505  3.032658  2.360656  0.320119  2.440177  1
# 85  1.725212  3.324380  8.049002  3.475788  2.602281  0.317648  3.051206  2
# 86  1.782814  3.359504  8.138838  3.425676  2.682823  0.214409  3.007878  2
# 87  1.792257  3.442149  7.794918  3.687500  2.615823  0.479918  3.199409  2
# 88  2.000000  3.555785  8.156987  3.701014  2.874555  0.751538  3.067947  2
# 89  1.971671  3.522727  8.195100  3.631757  2.873842  0.652199  3.112260  2
# 90  1.898017  3.510331  7.936479  3.705518  2.697790  0.254197  3.175283  2
# 91  1.771483  3.347107  8.152450  3.475225  2.705631  0.405674  2.980305  2
# 92  1.776204  3.365702  8.081670  3.531532  2.632217  0.420887  2.980305  2
# 93  1.755430  3.316116  8.226860  3.399212  2.751247  0.780273  2.893648  2
# 94  1.733711  3.413223  7.669691  3.753378  2.483963  0.641407  3.174791  2
# 95  1.593012  3.233471  7.847550  3.456644  2.468282  0.480568  2.937962  2
# 96  1.823418  3.427686  7.999093  3.570383  2.715609  0.452093  3.071393  2
# 97  1.792257  3.423554  7.882940  3.631194  2.531718  0.278771  3.177253  2
# 98  1.715770  3.359504  7.837568  3.530968  2.503207  0.370958  3.088626  2
# 99  1.767705  3.376033  7.994555  3.501689  2.625802  0.284492  3.001969  2
#
#        output  prediction
# 0   [1, 0, 0]           3
# 1   [1, 0, 0]           3
# 2   [1, 0, 0]           3
# 3   [1, 0, 0]           3
# 4   [1, 0, 0]           3
# 5   [1, 0, 0]           3
# 6   [1, 0, 0]           3
# 7   [1, 0, 0]           3
# 8   [1, 0, 0]           3
# 9   [1, 0, 0]           3
# 10  [1, 0, 0]           3
# 11  [1, 0, 0]           3
# 12  [1, 0, 0]           3
# 13  [1, 0, 0]           3
# 14  [1, 0, 0]           3
# 15  [1, 0, 0]           3
# 16  [1, 0, 0]           3
# 17  [1, 0, 0]           3
# 18  [1, 0, 0]           3
# 19  [1, 0, 0]           3
# 20  [1, 0, 0]           3
# 21  [1, 0, 0]           3
# 22  [1, 0, 0]           3
# 23  [1, 0, 0]           3
# 24  [1, 0, 0]           3
# 25  [1, 0, 0]           3
# 26  [1, 0, 0]           3
# 27  [1, 0, 0]           3
# 28  [1, 0, 0]           3
# 29  [1, 0, 0]           3
# ..        ...         ...
# 70  [0, 1, 0]           3
# 71  [0, 1, 0]           3
# 72  [0, 1, 0]           3
# 73  [0, 1, 0]           3
# 74  [0, 1, 0]           3
# 75  [0, 1, 0]           3
# 76  [0, 1, 0]           3
# 77  [0, 1, 0]           3
# 78  [0, 1, 0]           3
# 79  [0, 1, 0]           3
# 80  [0, 1, 0]           3
# 81  [0, 1, 0]           3
# 82  [0, 1, 0]           3
# 83  [0, 1, 0]           3
# 84  [0, 1, 0]           3
# 85  [0, 1, 0]           3
# 86  [0, 1, 0]           3
# 87  [0, 1, 0]           3
# 88  [0, 1, 0]           3
# 89  [0, 1, 0]           3
# 90  [0, 1, 0]           3
# 91  [0, 1, 0]           3
# 92  [0, 1, 0]           3
# 93  [0, 1, 0]           3
# 94  [0, 1, 0]           3
# 95  [0, 1, 0]           3
# 96  [0, 1, 0]           3
# 97  [0, 1, 0]           3
# 98  [0, 1, 0]           3
# 99  [0, 1, 0]           3
#
# [100 rows x 10 columns]
